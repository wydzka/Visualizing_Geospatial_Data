# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

import folium

# %% [markdown]
# No.1
# - Tampilkan rumah paling mahal
# - Tandai dengan icon pin berwarna merah
# - Beri tooltip berupa "Rumah Termahal"
# - Beri popup berupa alamat/address

# %%
df= pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df['Price'].max()
# Out:
# 9000000.0

# %%
df_max = df[(df['Price'] == df['Price'].max()) & (df['Type'] == 'h')]
df_max
# Out:
#          Suburb      Address  Rooms Type      Price Method SellerG  \
# 12094  Mulgrave  35 Bevis St      3    h  9000000.0     PI    Hall
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 12094  29/07/2017      18.8    3170.0  ...       1.0  1.0     744.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 12094         117.0     1960.0       Monash -37.93168   145.16126
#
#                        Regionname Propertycount
# 12094  South-Eastern Metropolitan        7113.0
#
# [1 rows x 21 columns]

# %%
longtitud = df_max['Longtitude'].values[0]
longtitud
# Out:
# 145.16126

# %%
lattitude = df_max['Lattitude'].values[0]
lattitude
# Out:
# -37.93168

# %%
## buat peta peta new york
# buat peta New York
melb_map = folium.Map(location=[lattitude, longtitud], zoom_start=12)
melb_map

# buat merker untuk liberty statu
# buat marker untuk Liberty Statue
melb_marker = folium.Marker(
    location=[lattitude, longtitud],
    tooltip='ini rumah termahal',
    popup='35 Bevis St',
    icon= folium.Icon(
                color='red',
                icon='home')
)


# # buat marker untuk wilayah broklin
# brooklyn_area = folium.Circle(
#     location=[longtitud, lattitude],
#     tooltip=' Area rawan Banjir',
#     popup='brooklyn',
#     radius= 2500



## memasukan marker ke map
melb_marker.add_to(melb_map)
# brooklyn_area.add_to(melb_map)

# menampilkan map
melb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# No.2
#
# - Ceritanya kita sedang mencari apartment (type='u') dengan 2 kamar tidur (Bedroom2) dengan harga yg murah
# - Coba tampilkan peta kota Melbourne
# - Berikan marker berupa pin pada 5 apartment termurah
# - Berikan tooltip berupa harga rumah
# - Berikan popup berupa Suburb dan Address

# %%
df['Bedroom2'].value_counts()
# Out:
# 3.0     5896
# 2.0     3737
# 4.0     2601
# 1.0      691
# 5.0      556
# 6.0       63
# 0.0       16
# 7.0       10
# 8.0        5
# 9.0        3
# 20.0       1
# 10.0       1
# Name: Bedroom2, dtype: int64

# %%
df_min = df[(df['Bedroom2'] == 2.0 ) & (df['Type'] == 'u')]
df_min
# Out:
#                  Suburb              Address  Rooms Type     Price Method  \
# 10           Abbotsford   411/8 Grosvenor St      2    u  700000.0     VB
# 12           Abbotsford  123/56 Nicholson St      2    u  750000.0      S
# 23           Abbotsford   6/219 Nicholson St      2    u  500000.0      S
# 44         Airport West     2/49 McIntosh St      2    u  500000.0     VB
# 49         Airport West         3/19 Hart St      2    u  515000.0      S
# ...                 ...                  ...    ...  ...       ...    ...
# 13453  Hoppers Crossing      3/14 Moffatt Cr      2    u  315000.0      S
# 13482      Malvern East      2002 Malvern Rd      2    u  651000.0     SP
# 13495      Moonee Ponds      1/53 Buckley St      2    u  435000.0      S
# 13510        Nunawading        3/39 Lemon Gr      2    u  710000.0      S
# 13530         Reservoir           92 Pine St      2    u  625500.0      S
#
#        SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df_min_sort = df_min.sort_values(by='Price', ascending=True)[0:5]
df_min_sort
# Out:
#          Suburb                Address  Rooms Type     Price Method  \
# 7303     Albion          8/6 Ridley St      1    u  145000.0     PI
# 7305     Albion         5/25 Ridley St      2    u  190000.0     SP
# 5205  Reservoir    1/164 Leamington St      1    u  216000.0      S
# 2915    Glenroy  14/854 Pascoe Vale Rd      2    u  230000.0     PI
# 5221  Reservoir         4/1067 High St      2    u  240000.0     PI
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 7303     Biggin  28/05/2016      13.9    3020.0  ...       1.0  1.0      36.0
# 7305    Burnham  30/07/2016      13.9    3020.0  ...       1.0  1.0       0.0
# 5205       Brad  24/09/2016      11.2    3073.0  ...       1.0  1.0       0.0
# 2915      Raine  18/03/2017      13.0    3046.0  ...       1.0  1.0    1996.0
# 5221  Stockdale  26/07/2016      11.2    3073.0  ...       1.0  1.0      82.0
#
#       BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
rumah_1 = [df_min_sort['Lattitude'].values[0], df_min_sort['Longtitude'].values[0]]
rumah_2 = [df_min_sort['Lattitude'].values[1], df_min_sort['Longtitude'].values[1]]
rumah_3 = [df_min_sort['Lattitude'].values[2], df_min_sort['Longtitude'].values[2]]
rumah_4 = [df_min_sort['Lattitude'].values[3], df_min_sort['Longtitude'].values[3]]
rumah_5 = [df_min_sort['Lattitude'].values[4], df_min_sort['Longtitude'].values[4]]

# %%
rumah_1
# Out:
# [-37.7833, 144.8266]

# %%
## buat peta peta new york
# buat peta New York
melb_map = folium.Map(location=rumah_1, zoom_start=12)
melb_map

# buat marker untuk Liberty Statue
melb_marker_1 = folium.Marker(
    location= rumah_1,
    tooltip='ini rumah termahal',
    popup='35 Bevis St',
    icon= folium.Icon(
                color='red',
                icon='home')
)

melb_marker_2 = folium.Marker(
    location= rumah_2,
    tooltip='ini rumah termahal',
    popup='35 Bevis St',
    icon= folium.Icon(
                color='red',
                icon='home')
)

melb_marker_3 = folium.Marker(
    location=rumah_3,
    tooltip='ini rumah termahal',
    popup='35 Bevis St',
    icon= folium.Icon(
                color='red',
                icon='home')
)

melb_marker_4 = folium.Marker(
    location=rumah_4,
    tooltip='ini rumah termahal',
    popup='35 Bevis St',
    icon= folium.Icon(
                color='red',
                icon='home')
)

melb_marker_5 = folium.Marker(
    location=rumah_5,
    tooltip='ini rumah termahal',
    popup='35 Bevis St',
    icon= folium.Icon(
                color='red',
                icon='home')
)


# # buat marker untuk wilayah broklin
# brooklyn_area = folium.Circle(
#     location=[longtitud, lattitude],
#     tooltip=' Area rawan Banjir',
#     popup='brooklyn',
#     radius= 2500



## memasukan marker ke map
melb_marker_1.add_to(melb_map)
melb_marker_2.add_to(melb_map)
melb_marker_3.add_to(melb_map)
melb_marker_4.add_to(melb_map)
melb_marker_5.add_to(melb_map)


# menampilkan map
melb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
## buat peta peta new york
# buat peta New York
melb_map = folium.Map(location=rumah_1, zoom_start=12)
melb_map

counter = 0
for i in range(len(df_min_sort)):
    addres = df_min_sort.iloc[i, 1]
    latttitude= df_min_sort.iloc[i,-4]
    longtitude= df_min_sort.iloc[i,-3]
    counter = counter + 1


    marker_min = folium.Marker(
        location= [latttitude, longtitude],
        tooltip= 'harga rumah',
        popup= addres
    )

    marker_min.add_to(melb_map)
    
melb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
